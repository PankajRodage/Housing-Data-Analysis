# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Ames_Housing_Subset.csv',index_col=0)
df
# Out:
#           Neighborhood  Year Built  Overall Qual Kitchen Qual Exter Qual  \
# PID
# 526301100        NAmes        1960             6           TA         TA
# 526350040        NAmes        1961             5           TA         TA
# 526351010        NAmes        1958             6           Gd         TA
# 526353030        NAmes        1968             7           Ex         Gd
# 527105010      Gilbert        1997             5           TA         TA
# ...                ...         ...           ...          ...        ...
# 923275080      Mitchel        1984             6           TA         TA
# 923276100      Mitchel        1983             5           TA         TA
# 923400125      Mitchel        1992             5           TA         TA
# 924100070      Mitchel        1974             5           TA         TA
# 924151050      Mitchel        1993             7           TA         TA
#
#            Lot Area  SalePrice
# PID
# 526301100     31770     215000
# ...

# %%
# Display the by default 5 rows of dataset

df.head()  #show first 5 rows
# Out:
#           Neighborhood  Year Built  Overall Qual Kitchen Qual Exter Qual  \
# PID
# 526301100        NAmes        1960             6           TA         TA
# 526350040        NAmes        1961             5           TA         TA
# 526351010        NAmes        1958             6           Gd         TA
# 526353030        NAmes        1968             7           Ex         Gd
# 527105010      Gilbert        1997             5           TA         TA
#
#            Lot Area  SalePrice
# PID
# 526301100     31770     215000
# 526350040     11622     105000
# 526351010     14267     172000
# 526353030     11160     244000
# 527105010     13830     189900

# %%
# Display the first 10 rows of dataset
df.head(10)
# Out:
#           Neighborhood  Year Built  Overall Qual Kitchen Qual Exter Qual  \
# PID
# 526301100        NAmes        1960             6           TA         TA
# 526350040        NAmes        1961             5           TA         TA
# 526351010        NAmes        1958             6           Gd         TA
# 526353030        NAmes        1968             7           Ex         Gd
# 527105010      Gilbert        1997             5           TA         TA
# 527105030      Gilbert        1998             6           Gd         TA
# 527127150      StoneBr        2001             8           Gd         Gd
# 527145080      StoneBr        1992             8           Gd         Gd
# 527146030      StoneBr        1995             8           Gd         Gd
# 527162130      Gilbert        1999             7           Gd         TA
#
#            Lot Area  SalePrice
# PID
# 526301100     31770     215000
# 526350040     11622     105000
# 526351010     14267     172000
# ...

# %%
# Display the last 10 rows of dataset
df.tail(10)
# Out:
#           Neighborhood  Year Built  Overall Qual Kitchen Qual Exter Qual  \
# PID
# 923228310      MeadowV        1970             4           TA         TA
# 923229110      Mitchel        1976             6           TA         TA
# 923230040      Mitchel        1976             5           TA         TA
# 923250060      Mitchel        1977             5           TA         TA
# 923251180      Mitchel        1960             5           TA         TA
# 923275080      Mitchel        1984             6           TA         TA
# 923276100      Mitchel        1983             5           TA         TA
# 923400125      Mitchel        1992             5           TA         TA
# 924100070      Mitchel        1974             5           TA         TA
# 924151050      Mitchel        1993             7           TA         TA
#
#            Lot Area  SalePrice
# PID
# 923228310      1894      71000
# 923229110     12640     150900
# 923230040      9297     188000
# ...

# %%
df.shape
# Out:
# (2930, 7)

# %%
# Read txt file
with open('Ames_Housing_Subset_Feature_Description.txt','r') as f:
    print(f.read())
# Out:
# PID: Property ID of the house
#
# Neighborhood: Physical locations within Ames city limits
#
#        Blmngtn	Bloomington Heights
#        Blueste	Bluestem
#        BrDale	Briardale
#        BrkSide	Brookside
#        ClearCr	Clear Creek
#        CollgCr	College Creek
#        Crawfor	Crawford
#        Edwards	Edwards
#        Gilbert	Gilbert
#        IDOTRR	Iowa DOT and Rail Road
#        MeadowV	Meadow Village
#        Mitchel	Mitchell
#        Names	North Ames
#        NoRidge	Northridge
#        NPkVill	Northpark Villa
#        NridgHt	Northridge Heights
#        NWAmes	Northwest Ames
#        OldTown	Old Town
#        SWISU	South & West of Iowa State University
#        Sawyer	Sawyer
#        SawyerW	Sawyer West
#        Somerst	Somerset
#        StoneBr	Stone Brook
#        Timber	Timberland
#        Veenker	Veenker
#
# Year Built: Original construction date
#
# Overall Qual: Rates the overall material and finish of the house
#
#        10	Very Excellent
#        9	Excellent
# ...

# %%
df.index
# Out:
# Index([526301100, 526350040, 526351010, 526353030, 527105010, 527105030,
#        527127150, 527145080, 527146030, 527162130,
#        ...
#        923228310, 923229110, 923230040, 923250060, 923251180, 923275080,
#        923276100, 923400125, 924100070, 924151050],
#       dtype='int64', name='PID', length=2930)

# %%
df.columns
# Out:
# Index(['Neighborhood', 'Year Built', 'Overall Qual', 'Kitchen Qual',
#        'Exter Qual', 'Lot Area', 'SalePrice'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2930 entries, 526301100 to 924151050
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Neighborhood  2930 non-null   object
#  1   Year Built    2930 non-null   int64
#  2   Overall Qual  2930 non-null   int64
#  3   Kitchen Qual  2930 non-null   object
#  4   Exter Qual    2930 non-null   object
#  5   Lot Area      2930 non-null   int64
#  6   SalePrice     2930 non-null   int64
# dtypes: int64(4), object(3)
# memory usage: 183.1+ KB

# %%
df.isnull().sum()
# Out:
# Neighborhood    0
# Year Built      0
# Overall Qual    0
# Kitchen Qual    0
# Exter Qual      0
# Lot Area        0
# SalePrice       0
# dtype: int64

# %%
plt.figure(figsize=(6,4))

sns.countplot(data=df,x='Neighborhood',color='b')
plt.title('Housing data by Neighborhood')
plt.xlabel('Neighborhood')
plt.ylabel('Number of Houses')
plt.xticks(rotation=90)
plt.savefig('housing plot.jpeg',format='jpeg')
plt.show()

# %%
# check the minimum and maximum values of year built
print(df['Year Built'].min())
print(df['Year Built'].max())
# Out:
# 1872
# 2010

# %%
# Check the mean,median and mode sale price
print(df['SalePrice'].mean())
print(df['SalePrice'].median())
print(df['SalePrice'].mode())
# Out:
# 180796.0600682594
# 160000.0
# 0    135000
# Name: SalePrice, dtype: int64

# %%
# creating a histogram of the 'Year Built' feature and also showing the mean and median
plt.figure(figsize=(6,4))
sns.histplot(data=df,x='Year Built',color='orange',edgecolor='yellow')
plt.vlines(x=df['Year Built'].mean(),ymin=0,ymax=575,color='b',label='Mean')
plt.vlines(x=df['Year Built'].median(),ymin=0,ymax=575,color='k',label='Median')
plt.vlines(x=df['Year Built'].mode(),ymin=0,ymax=575,color='r',label='Mode')
plt.show()
# Out:
# C:\Users\s\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# creating a histogram of the 'SalePrice' feature and also showing the mean and median

plt.figure(figsize=(6,4))
sns.histplot(data=df,x='SalePrice',color='orange',edgecolor='yellow')
plt.vlines(x=df['SalePrice'].mean(),ymin=0,ymax=350,color='b',label='Mean')
plt.vlines(x=df['SalePrice'].median(),ymin=0,ymax=350,color='k',label='Median')
plt.vlines(x=df['SalePrice'].mode(),ymin=0,ymax=350,color='r',label='Mode')
plt.show()
# Out:
# C:\Users\s\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# 1. box pot for year built
# 2. check max and min of sale price
# 3. range of sale price
# 4. create a histogram of sale price also showing mean, median and mode
# 5. box plot for sale price
# 6. create a histogram, box plot of lot area also showing mean, median and mode
# 7. scatter plot of lot area and sale price
# 8. Create a new feature (column) called Price per Area in the data frame to contain ratio of "SalePrice" and "Lot Area" features
# 9. Check if the new column is created using head()
# 10. Create a histogram, box plot of the "Price per Area" feature and also showing the mean and the median
# 11. Create a scatter plot between lot area and price per area

# %%
# 1.box pot for year built
plt.figure(figsize=(6,3))
plt.boxplot(df['Year Built'])
plt.show()

# %%
# 2.check max and min of sale price
print(df['SalePrice'].max())
print(df['SalePrice'].min())
# Out:
# 755000
# 12789

# %%
# 3.range of sale price
print(df['SalePrice'].max() - df['SalePrice'].min())
# Out:
# 742211

# %%
# 4.create a histogram of sale price also showing mean, median and mode
plt.figure(figsize=(6,4))
sns.histplot(data=df,x='SalePrice',color='pink',edgecolor='yellow')
plt.vlines(x=df['SalePrice'].mean(),ymin=0,ymax=350,color='r',label='Mean')
plt.vlines(x=df['SalePrice'].median(),ymin=0,ymax=350,color='b',label='Median')
plt.vlines(x=df['SalePrice'].mode(),ymin=0,ymax=350,color='k',label='Mode')
plt.show()
# Out:
# C:\Users\s\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# 5.box plot for sale price
plt.figure(figsize=(6,4))
plt.boxplot(df['SalePrice'])
plt.show()

# %%
# 6.create a histogram lot area also showing mean, median and mode
plt.figure(figsize=(6,4))
sns.histplot(data=df,x='Lot Area',color='orange',edgecolor='yellow')
plt.vlines(x=df['Lot Area'].mean(),ymin=0,ymax=250,color='r',label='Mean')
plt.vlines(x=df['Lot Area'].median(),ymin=0,ymax=250,color='k',label='Median')
plt.vlines(x=df['Lot Area'].mode(),ymin=0,ymax=250,color='g',label='Mode')
plt.show()
# Out:
# C:\Users\s\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# 6. box plot of lot area
plt.figure(figsize=(6,4))
plt.boxplot(df['Lot Area'])
plt.show()

# %%
# 7.scatter plot of lot area and sale price
sns.scatterplot(x=df['Lot Area'],y=df['SalePrice'],data=df,palette='viridis',sizes=(5,100))
plt.show()
# Out:
# C:\Users\s\AppData\Local\Temp\ipykernel_11388\291905990.py:2: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(x=df['Lot Area'],y=df['SalePrice'],data=df,palette='viridis',sizes=(5,100))

# %%
# 8. Create a new feature (column) called Price per Area in the data frame to contain ratio of "SalePrice" and "Lot Area" features
df['Price per Area ']= df['SalePrice'] / df['Lot Area']

# %%
# 9. Check if the new column is created using head()
df.head()
# Out:
#           Neighborhood  Year Built  Overall Qual Kitchen Qual Exter Qual  \
# PID
# 526301100        NAmes        1960             6           TA         TA
# 526350040        NAmes        1961             5           TA         TA
# 526351010        NAmes        1958             6           Gd         TA
# 526353030        NAmes        1968             7           Ex         Gd
# 527105010      Gilbert        1997             5           TA         TA
#
#            Lot Area  SalePrice  Price per Area
# PID
# 526301100     31770     215000         6.767391
# 526350040     11622     105000         9.034590
# 526351010     14267     172000        12.055793
# 526353030     11160     244000        21.863799
# 527105010     13830     189900        13.731020

# %%
# 10. Create a histogram of the "Price per Area" feature and also showing the mean and the median
df['Price per Area'] = df['SalePrice'] / df['Lot Area']
plt.figure(figsize=(6,4))
sns.histplot(data=df,x='Price per Area',color='orange',edgecolor='yellow')
plt.vlines(x=df['Price per Area'].mean(),ymin=0,ymax=350,color='b',label='Mean')
plt.vlines(x=df['Price per Area'].median(),ymin=0,ymax=350,color='k',label='Median')
plt.vlines(x=df['Price per Area'].mode(),ymin=0,ymax=350,color='g',label='Mode')
plt.show()
# Out:
# C:\Users\s\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# 10. box plot of the "Price per Area"
df['Price per Area'] = df['SalePrice'] / df['Lot Area']
plt.figure(figsize=(6,4))
plt.boxplot(df['Price per Area'])
plt.show()

# %%
# 11. Create a scatter plot between lot area and price per area
df['Price per Area'] = df['SalePrice'] / df['Lot Area']
sns.scatterplot(x=df['Lot Area'],y=df['Price per Area'],data=df,palette='viridis',sizes=(5,100))
plt.show()
# Out:
# C:\Users\s\AppData\Local\Temp\ipykernel_11388\2496473031.py:3: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(x=df['Lot Area'],y=df['Price per Area'],data=df,palette='viridis',sizes=(5,100))

# %% [markdown]
# :
